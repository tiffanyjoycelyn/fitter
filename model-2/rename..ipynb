# %%
import os
count = 0

for file in os.listdir("./dataset/ayam_goreng"):
    src = f"./dataset/ayam_goreng/{file}"
    dst = f"./dataset/ayam_goreng/ayam_goreng_{count}.png"
    os.rename(src, dst)
    count += 1;

count = 0
for file in os.listdir("./dataset/gulai_tambusu"):
    src = f"./dataset/gulai_tambusu/{file}"
    dst = f"./dataset/gulai_tambusu/gulai_tambusu_{count}.png"
    os.rename(src, dst)
    count += 1;

count = 0
for file in os.listdir("./dataset/ayam_pop"):
    src = f"./dataset/ayam_pop/{file}"
    dst = f"./dataset/ayam_pop/ayam_pop_{count}.png"
    os.rename(src, dst)
    count += 1;

count = 0
for file in os.listdir("./dataset/gulai_ikan"):
    src = f"./dataset/gulai_ikan/{file}"
    dst = f"./dataset/gulai_ikan/gulai_ikan_{count}.png"
    os.rename(src, dst)
    count += 1;

count = 0
for file in os.listdir("./dataset/telur_balado"):
    src = f"./dataset/telur_balado/{file}"
    dst = f"./dataset/telur_balado/telur_balado_{count}.png"
    os.rename(src, dst)
    count += 1

count = 0
for file in os.listdir("./dataset/telur_dadar"):
    src = f"./dataset/telur_dadar/{file}"
    dst = f"./dataset/telur_dadar/telur_dadar_{count}.png"
    os.rename(src, dst)
    count += 1

count = 0
for file in os.listdir("./dataset/daging_rendang"):
    src = f"./dataset/daging_rendang/{file}"
    dst = f"./dataset/daging_rendang/daging_rendang_{count}.png"
    os.rename(src, dst)
    count += 1

count = 0
for file in os.listdir("./dataset/dendeng_batokok"):
    src = f"./dataset/dendeng_batokok/{file}"
    dst = f"./dataset/dendeng_batokok/dendeng_{count}.png"
    os.rename(src, dst)
    count += 1
    
count = 0
for file in os.listdir("./dataset/tahu"):
    src = f"./dataset/tahu/{file}"
    dst = f"./dataset/tahu/tahu_{count}.png"
    os.rename(src, dst)
    count += 1
    
count = 0
for file in os.listdir("./dataset/nangka"):
    src = f"./dataset/nangka/{file}"
    dst = f"./dataset/nangka/nangka_{count}.png"
    os.rename(src, dst)
    count += 1
    
count = 0
for file in os.listdir("./dataset/perkedel"):
    src = f"./dataset/perkedel/{file}"
    dst = f"./dataset/perkedel/perkedel_{count}.png"
    os.rename(src, dst)
    count += 1

count = 0
for file in os.listdir("./dataset/daun_singkong"):
    src = f"./dataset/daun_singkong/{file}"
    dst = f"./dataset/daun_singkong/daun_singkong_{count}.png"
    os.rename(src, dst)
    count += 1
    
count = 0
for file in os.listdir("./dataset/nasi"):
    src = f"./dataset/nasi/{file}"
    dst = f"./dataset/nasi/nasi_{count}.png"
    os.rename(src, dst)
    count += 1

# %%
import os
count = 0
for file in os.listdir("./dataset/tempe_goreng"):
    src = f"./dataset/tempe_goreng/{file}"
    dst = f"./dataset/tempe_goreng/tempe_goreng_{count}.png"
    os.rename(src, dst)
    count += 1

# %%
count = 0
for file in os.listdir("./dataset/perkedel"):
    src = f"./dataset/perkedel/{file}"
    dst = f"./dataset/perkedel/perkedel1_{count}.png"
    os.rename(src, dst)
    count += 1
